# %%
test_json = {
	"key": "v",
	"value": "ganaga",
	"key_2": "k",
	"value_2": "kaveri"
}

# %%
print(test_json)
# Out:
# {'key': 'v', 'value': 'ganaga', 'key_2': 'k', 'value_2': 'kaveri'}

# %%
json_2 = {
	"key": "v",
	"value": "ganaga",
	"key": "k",
	"value_2": "kaveri"
}

# %%
print(json_2)
# Out:
# {'key': 'k', 'value': 'ganaga', 'value_2': 'kaveri'}

# %%
url = "https://api.esdcgcek.in/api/users"

# %%
# !pip install requests

# %%
import requests
