# %%
test_json = {
	"key": "v",
	"value": "ganaga",
	"key_2": "k",
	"value_2": "kaveri"
}

# %%
print(test_json)
# Out:
# {'key': 'v', 'value': 'ganaga', 'key_2': 'k', 'value_2': 'kaveri'}

# %%
json_2 = {
	"key": "v",
	"value": "ganaga",
	"key": "k",
	"value_2": "kaveri"
}

# %%
print(json_2)
# Out:
# hi

# %%
# %pip install requests

# %%
import requests
url = "https://api.esdcgcek.in/api/login"

# %% [markdown]
# #### LOGIN

# %%
from dataclasses import asdict
import json
import requests

email = "ganga@gamil.com"
password = "gangav"

url = "https://api.esdcgcek.in/api/login"


response = requests.post(url, json={"email": email, "password": password})
print(response.status_code)

json_data = response.json()


print(json.dumps(json_data, indent=2))
# Out:
# 200
# {
#   "token": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3NzM3NjQzMjEsInJvbGUiOiJ0ZWFjaGVyIiwidXNlcl9pZCI6ImIyOWQxMjcxLWVlNDQtNDNmNS1hZmFhLWViNjk1ZTkxZmUxZiJ9.KviN63uNewZv8X3Qtt7NZvdSbwWyZL-jCvsISWea_Fw",
#   "user": {
#     "id": "b29d1271-ee44-43f5-afaa-eb695e91fe1f",
#     "first_name": "Ganga",
#     "last_name": "V",
#     "email": "ganga@gamil.com",
#     "role": "teacher"
#   }
# }
